# %%
import numpy as np
import pandas as pd
import random

order_list = [1,2,3,4,5,6]

np_order = np.zeros((4,6))

saved_order = np.array(
    [[6., 3., 4., 5., 1., 2.],
     [5., 6., 2., 1., 3., 4.],
     [1., 4., 2., 6., 5., 3.],
     [6., 1., 5., 3., 4., 2.]])


for row in range(np_order.shape[0]):
    random.shuffle(order_list)
    np_order[row] = order_list


# np_order = saved_order

df = pd.DataFrame(data=np_order, index=["Whatsapp", "Instagram", "Facebook Messenger", "WeChat"], 
                  columns=["MM-P2", "ML-P2", "MH-P2", "MM-P10", "ML-P10", "MH-P10"]).astype(int)
df
# Out:
#                     MM-P2  ML-P2  MH-P2  MM-P10  ML-P10  MH-P10
# Whatsapp                6      3      4       5       1       2
# Instagram               5      6      2       1       3       4
# Facebook Messenger      1      4      2       6       5       3
# WeChat                  6      1      5       3       4       2

# %%
np_order = np.zeros((4,4))

df = pd.DataFrame(data=np_order, index=["Whatsapp", "Instagram", "Facebook Messenger", "WeChat"], 
                  columns=["ML-P6", "MM-P2", "ML-P2", "MH-P2"]).astype(int)
df
# Out:
#                     ML-P6  MM-P2  ML-P2  MH-P2
# Whatsapp                0      0      0      0
# Instagram               0      0      0      0
# Facebook Messenger      0      0      0      0
# WeChat                  0      0      0      0
